# %% [markdown]
# ## EDA for the Airbnb data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading Data from google drive

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_newyork = pd.read_csv("/content/drive/MyDrive/Capstone/listings_Newyork.csv")
df_newjersey = pd.read_csv("/content/drive/MyDrive/Capstone/listings_Newjersey.csv")
df_washington_DC = pd.read_csv("/content/drive/MyDrive/Capstone/listings_washington_DC.csv")
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (68) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### Printing top 5 rows in a dataset

# %%
df_newyork.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20221204162430   2022-12-05
# 1  5203  https://www.airbnb.com/rooms/5203  20221204162430   2022-12-05
# 2  5136  https://www.airbnb.com/rooms/5136  20221204162430   2022-12-04
# 3  5121  https://www.airbnb.com/rooms/5121  20221204162430   2022-12-05
# 4  6848  https://www.airbnb.com/rooms/6848  20221204162430   2022-12-05
#
#             source                                      name  \
# 0      city scrape                     Skylit Midtown Castle
# 1  previous scrape        Cozy Clean Guest Room - Family Apt
# 2      city scrape  Spacious Brooklyn Duplex, Patio + Garden
# 3      city scrape                           BlissArtsSpace!
# 4      city scrape          Only 2 stops to Manhattan studio
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Our best guests are seeking a safe, clean, spa...
# ...

# %%
df_newyork['location'] = 'New york' # assigning New york column to New york dataset

# %%
df_newjersey.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0    62033    https://www.airbnb.com/rooms/62033  20221230232109   2022-12-31
# 1  1975091  https://www.airbnb.com/rooms/1975091  20221230232109   2022-12-31
# 2  2159185  https://www.airbnb.com/rooms/2159185  20221230232109   2022-12-31
# 3  2277901  https://www.airbnb.com/rooms/2277901  20221230232109   2022-12-31
# 4  2278440  https://www.airbnb.com/rooms/2278440  20221230232109   2022-12-31
#
#         source                                             name  \
# 0  city scrape               LARGE BEDROOM IN HISTORIC DISTRICT
# 1  city scrape               Hello World, Welcome to Newark!!!!
# 2  city scrape  Hello World!  Zen room. New photos coming soon.
# 3  city scrape       Luxury Muwuyu Queen enSuite @MushaindoroHS
# 4  city scrape        Luxury Musasa Queen Suite @ MushaindoroHS
#
#                                          description  \
# 0  <b>The space</b><br />LOCATED IN HISTORIC FORE...
# ...

# %%
df_newjersey['location'] = 'New Jersey'

# %%
df_washington_DC.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0    3686    https://www.airbnb.com/rooms/3686  20221220053924   2022-12-20
# 1  196429  https://www.airbnb.com/rooms/196429  20221220053924   2022-12-20
# 2  198685  https://www.airbnb.com/rooms/198685  20221220053924   2022-12-20
# 3  201116  https://www.airbnb.com/rooms/201116  20221220053924   2022-12-20
# 4  204741  https://www.airbnb.com/rooms/204741  20221220053924   2022-12-20
#
#         source                                   name  \
# 0  city scrape                        Vita's Hideaway
# 1  city scrape    Takoma Garden apt-Lush yard,pets ok
# 2  city scrape      Private room in central location.
# 3  city scrape    Victorian Haven - Private Basement!
# 4  city scrape  1-Suburbia in the City--Best Value!!!
#
#                                          description  \
# 0  IMPORTANT NOTES<br />* Carefully read and be s...
# 1  Private Garden apt in SF home with Full size b...
# ...

# %%
df_washington_DC['location'] = 'Washington D.C'

# %% [markdown]
# ### Printing shape of datasets

# %%
df_newyork.shape
# Out:
# (41533, 76)

# %%
df_newjersey.shape
# Out:
# (1260, 76)

# %%
df_washington_DC.shape
# Out:
# (6217, 76)

# %% [markdown]
# ### info and data types for the dataset

# %%
df_newyork.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41533 entries, 0 to 41532
# Data columns (total 76 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            41533 non-null  int64
#  1   listing_url                                   41533 non-null  object
#  2   scrape_id                                     41533 non-null  int64
#  3   last_scraped                                  41533 non-null  object
#  4   source                                        41533 non-null  object
#  5   name                                          41520 non-null  object
#  6   description                                   40747 non-null  object
#  7   neighborhood_overview                         24089 non-null  object
#  8   picture_url                                   41533 non-null  object
# ...

# %%
df_newjersey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 76 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            1260 non-null   int64
#  1   listing_url                                   1260 non-null   object
#  2   scrape_id                                     1260 non-null   int64
#  3   last_scraped                                  1260 non-null   object
#  4   source                                        1260 non-null   object
#  5   name                                          1260 non-null   object
#  6   description                                   1210 non-null   object
#  7   neighborhood_overview                         633 non-null    object
#  8   picture_url                                   1260 non-null   object
# ...

# %%
df_washington_DC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6217 entries, 0 to 6216
# Data columns (total 76 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            6217 non-null   int64
#  1   listing_url                                   6217 non-null   object
#  2   scrape_id                                     6217 non-null   int64
#  3   last_scraped                                  6217 non-null   object
#  4   source                                        6217 non-null   object
#  5   name                                          6217 non-null   object
#  6   description                                   6165 non-null   object
#  7   neighborhood_overview                         4155 non-null   object
#  8   picture_url                                   6217 non-null   object
# ...

# %% [markdown]
# ### Summary of dataset

# %%
df_newyork.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  4.153300e+04  4.153300e+04  4.153300e+04         41528.000000
# mean   1.728318e+17  2.022120e+13  1.400636e+08            86.616211
# std    2.974371e+17  0.000000e+00  1.526932e+08           518.345903
# min    2.595000e+03  2.022120e+13  2.438000e+03             1.000000
# 25%    1.835861e+07  2.022120e+13  1.491162e+07             1.000000
# 50%    4.117861e+07  2.022120e+13  6.561181e+07             2.000000
# 75%    5.477978e+17  2.022120e+13  2.418897e+08             5.000000
# max    7.741268e+17  2.022120e+13  4.899967e+08          4559.000000
#
#        host_total_listings_count      latitude     longitude  accommodates  \
# count               41528.000000  41533.000000  41533.000000  41533.000000
# mean                  136.263316     40.728292    -73.944526      2.958178
# std                   773.512816      0.057145      0.055965      2.078531
# ...

# %%
df_newjersey.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  1.260000e+03  1.260000e+03  1.260000e+03          1260.000000
# mean   3.227006e+17  2.022123e+13  2.482281e+08            17.404762
# std    3.533176e+17  0.000000e+00  1.553622e+08            48.772702
# min    6.203300e+04  2.022123e+13  1.727000e+04             1.000000
# 25%    4.418791e+07  2.022123e+13  8.832780e+07             2.000000
# 50%    5.334671e+07  2.022123e+13  2.478243e+08             6.000000
# 75%    7.121360e+17  2.022123e+13  3.928982e+08            20.000000
# max    7.927869e+17  2.022123e+13  4.933660e+08           800.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                1260.000000                           0.0  1260.000000
# mean                   26.545238                           NaN    40.734886
# std                    86.398730                           NaN     0.018309
# ...

# %%
df_washington_DC.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  6.217000e+03  6.217000e+03  6.217000e+03          6217.000000
# mean   1.507328e+17  2.022122e+13  1.154536e+08           250.971047
# std    2.841390e+17  0.000000e+00  1.327067e+08           890.629849
# min    3.686000e+03  2.022122e+13  4.492000e+03             1.000000
# 25%    2.084250e+07  2.022122e+13  1.601717e+07             1.000000
# 50%    4.187946e+07  2.022122e+13  5.038247e+07             3.000000
# 75%    5.353049e+07  2.022122e+13  1.747920e+08            19.000000
# max    7.855798e+17  2.022122e+13  4.915968e+08          4608.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                6217.000000                           0.0  6217.000000
# mean                  356.891748                           NaN    38.910146
# std                  1210.126587                           NaN     0.024366
# ...

# %%
grouping_df = [df_newyork, df_newjersey, df_washington_DC]

# %%
final_df = pd.concat(grouping_df)

# %%
final_df
# Out:
#           id                          listing_url       scrape_id  \
# 0       2595    https://www.airbnb.com/rooms/2595  20221204162430
# 1       5203    https://www.airbnb.com/rooms/5203  20221204162430
# 2       5136    https://www.airbnb.com/rooms/5136  20221204162430
# 3       5121    https://www.airbnb.com/rooms/5121  20221204162430
# 4       6848    https://www.airbnb.com/rooms/6848  20221204162430
# ...      ...                                  ...             ...
# 6212  155859  https://www.airbnb.com/rooms/155859  20221220053924
# 6213  164069  https://www.airbnb.com/rooms/164069  20221220053924
# 6214  174808  https://www.airbnb.com/rooms/174808  20221220053924
# 6215  175608  https://www.airbnb.com/rooms/175608  20221220053924
# 6216  178395  https://www.airbnb.com/rooms/178395  20221220053924
#
#      last_scraped           source  \
# 0      2022-12-05      city scrape
# 1      2022-12-05  previous scrape
# 2      2022-12-04      city scrape
# ...
