# %% [markdown]
# ## EDA for the Airbnb data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading Data from google drive

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_newyork = pd.read_csv("/content/drive/MyDrive/Capstone/listing_NEWYORK.csv")
df_newjersey = pd.read_csv("/content/drive/MyDrive/Capstone/listing_NEWJERSEY.csv")
df_washington_DC = pd.read_csv("/content/drive/MyDrive/Capstone/listing_WASHINGTONDC.csv")
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### Creating a new column with name location to identify the location of the airbnb

# %%
df_newyork.head()
# Out:
#      id                                      name  host_id  host_name  \
# 0  5136  Spacious Brooklyn Duplex, Patio + Garden     7378    Rebecca
# 1  5203        Cozy Clean Guest Room - Family Apt     7490  MaryEllen
# 2  5121                           BlissArtsSpace!     7356      Garon
# 3  5178          Large Furnished Room Near B'way　     8967   Shunichi
# 4  2595                     Skylit Midtown Castle     2845   Jennifer
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0            Brooklyn         Sunset Park  40.66265  -73.99454
# 1           Manhattan     Upper West Side  40.80380  -73.96751
# 2            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 3           Manhattan             Midtown  40.76457  -73.98317
# 4           Manhattan             Midtown  40.75356  -73.98559
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    275              21                  3  2022-08-10
# ...

# %%
df_newyork['location'] = 'New york' # assigning New york column to New york dataset

# %%
df_newjersey.head()
# Out:
#         id                                             name   host_id  \
# 0    62033               LARGE BEDROOM IN HISTORIC DISTRICT    301435
# 1  1975091               Hello World, Welcome to Newark!!!!   9169027
# 2  2159185  Hello World!  Zen room. New photos coming soon.   9169027
# 3  2277901       Luxury Muwuyu Queen enSuite @MushaindoroHS  11308972
# 4  2278440        Luxury Musasa Queen Suite @ MushaindoroHS  11308972
#
#     host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0        Fred                  NaN         North  40.77146  -74.17054
# 1  Kimberly B                  NaN          West  40.74462  -74.19848
# 2  Kimberly B                  NaN          West  40.74478  -74.19575
# 3      Tendai                  NaN          West  40.73473  -74.24575
# 4      Tendai                  NaN          West  40.73471  -74.24787
#
#       room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df_newjersey['location'] = 'New Jersey'

# %%
df_washington_DC.head()
# Out:
#        id                                  name  host_id host_name  \
# 0  196429   Takoma Garden apt-Lush yard,pets ok   956417     Julia
# 1    3686                       Vita's Hideaway     4645      Vita
# 2    3943      Historic Rowhouse Near Monuments     5059      Vasa
# 3    4967                        DC, Near Metro     7086    Edward
# 4  888029  PERFECT ROOM FOR INTERNS OR STUDENTS   315148      John
#
#    neighbourhood_group                                      neighbourhood  \
# 0                  NaN                     Takoma, Brightwood, Manor Park
# 1                  NaN                                 Historic Anacostia
# 2                  NaN  Edgewood, Bloomingdale, Truxton Circle, Eckington
# 3                  NaN  Edgewood, Bloomingdale, Truxton Circle, Eckington
# 4                  NaN               Brightwood Park, Crestwood, Petworth
#
#    latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
df_washington_DC.neighbourhood_group.isna().sum()
# Out:
# 6217

# %%
df_newjersey.neighbourhood_group.isna().sum()
# Out:
# 1260

# %%
df_washington_DC['location'] = 'Washington D.C'

# %% [markdown]
# ### Printing shape of datasets

# %%
df_newyork.shape
# Out:
# (41533, 19)

# %%
df_newjersey.shape
# Out:
# (1260, 19)

# %%
df_washington_DC.shape
# Out:
# (6217, 19)

# %% [markdown]
# ### info and data types for the dataset

# %%
df_newyork.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41533 entries, 0 to 41532
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              41533 non-null  int64
#  1   name                            41520 non-null  object
#  2   host_id                         41533 non-null  int64
#  3   host_name                       41528 non-null  object
#  4   neighbourhood_group             41533 non-null  object
#  5   neighbourhood                   41533 non-null  object
#  6   latitude                        41533 non-null  float64
#  7   longitude                       41533 non-null  float64
#  8   room_type                       41533 non-null  object
#  9   price                           41533 non-null  int64
#  10  minimum_nights                  41533 non-null  int64
#  11  number_of_reviews               41533 non-null  int64
# ...

# %%
df_newjersey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1260 non-null   int64
#  1   name                            1260 non-null   object
#  2   host_id                         1260 non-null   int64
#  3   host_name                       1260 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   1260 non-null   object
#  6   latitude                        1260 non-null   float64
#  7   longitude                       1260 non-null   float64
#  8   room_type                       1260 non-null   object
#  9   price                           1260 non-null   int64
#  10  minimum_nights                  1260 non-null   int64
#  11  number_of_reviews               1260 non-null   int64
# ...

# %%
df_washington_DC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6217 entries, 0 to 6216
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              6217 non-null   int64
#  1   name                            6217 non-null   object
#  2   host_id                         6217 non-null   int64
#  3   host_name                       6217 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   6217 non-null   object
#  6   latitude                        6217 non-null   float64
#  7   longitude                       6217 non-null   float64
#  8   room_type                       6217 non-null   object
#  9   price                           6217 non-null   int64
#  10  minimum_nights                  6217 non-null   int64
#  11  number_of_reviews               6217 non-null   int64
# ...

# %% [markdown]
# ### Summary of dataset

# %%
df_newyork.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.153300e+04  4.153300e+04  41533.000000  41533.000000  41533.000000
# mean   1.728318e+17  1.400636e+08     40.728292    -73.944526    221.978282
# std    2.974371e+17  1.526932e+08      0.057145      0.055965    919.502236
# min    2.595000e+03  2.438000e+03     40.500314    -74.249840      0.000000
# 25%    1.835861e+07  1.491162e+07     40.687750    -73.982410     80.000000
# 50%    4.117861e+07  6.561181e+07     40.723830    -73.953156    131.000000
# 75%    5.477978e+17  2.418897e+08     40.762200    -73.924990    220.000000
# max    7.741268e+17  4.899967e+08     40.911380    -73.710870  98159.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    41533.000000       41533.000000       32140.000000
# mean        18.592204          26.204994           1.279287
# std         30.699921          56.178847           1.935098
# ...

# %%
df_newjersey.describe()
# Out:
#                  id       host_id  neighbourhood_group     latitude  \
# count  1.260000e+03  1.260000e+03                  0.0  1260.000000
# mean   3.227006e+17  2.482281e+08                  NaN    40.734886
# std    3.533176e+17  1.553622e+08                  NaN     0.018309
# min    6.203300e+04  1.727000e+04                  NaN    40.686980
# 25%    4.418791e+07  8.832780e+07                  NaN    40.722282
# 50%    5.334671e+07  2.478243e+08                  NaN    40.735365
# 75%    7.121360e+17  3.928982e+08                  NaN    40.746493
# max    7.927869e+17  4.933660e+08                  NaN    40.783610
#
#          longitude        price  minimum_nights  number_of_reviews  \
# count  1260.000000  1260.000000     1260.000000        1260.000000
# mean    -74.190626   126.019841        3.446032          28.088889
# std       0.021173   289.630041        6.638117          51.730606
# min     -74.248710    25.000000        1.000000           0.000000
# ...

# %%
df_washington_DC.describe()
# Out:
#                  id       host_id  neighbourhood_group     latitude  \
# count  6.217000e+03  6.217000e+03                  0.0  6217.000000
# mean   1.507328e+17  1.154536e+08                  NaN    38.910146
# std    2.841390e+17  1.327067e+08                  NaN     0.024366
# min    3.686000e+03  4.492000e+03                  NaN    38.820780
# 25%    2.084250e+07  1.601717e+07                  NaN    38.897556
# 50%    4.187946e+07  5.038247e+07                  NaN    38.909550
# 75%    5.353049e+07  1.747920e+08                  NaN    38.922870
# max    7.855798e+17  4.915968e+08                  NaN    38.992140
#
#          longitude         price  minimum_nights  number_of_reviews  \
# count  6217.000000   6217.000000     6217.000000        6217.000000
# mean    -77.015140    178.202509       21.811163          51.725591
# std       0.030696    705.550802       40.717326          87.497018
# min     -77.109000      0.000000        1.000000           0.000000
# ...

# %%
grouping_df = [df_newyork, df_newjersey, df_washington_DC]

# %%
final_df = pd.concat(grouping_df)

# %%
final_df
# Out:
#             id                                               name   host_id  \
# 0         5136           Spacious Brooklyn Duplex, Patio + Garden      7378
# 1         5203                 Cozy Clean Guest Room - Family Apt      7490
# 2         5121                                    BlissArtsSpace!      7356
# 3         5178                   Large Furnished Room Near B'way　      8967
# 4         2595                              Skylit Midtown Castle      2845
# ...        ...                                                ...       ...
# 6212  13853404                                  A Petite Elegance  81822679
# 6213  13894976    Perfect location, wonderful home for a DC stay.  81929011
# 6214  13913413      Bright cozy room in Columbia Heights rowhouse  18594116
# 6215  13913758       Brand New Luxury Studio in Shaw, Pro cleaned  70098073
# 6216  13926632  Elegant Bedroom in Georgetown - parking available   7196325
#
#       host_name neighbourhood_group  \
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49010 entries, 0 to 6216
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              49010 non-null  int64
#  1   name                            48997 non-null  object
#  2   host_id                         49010 non-null  int64
#  3   host_name                       49005 non-null  object
#  4   neighbourhood_group             41533 non-null  object
#  5   neighbourhood                   49010 non-null  object
#  6   latitude                        49010 non-null  float64
#  7   longitude                       49010 non-null  float64
#  8   room_type                       49010 non-null  object
#  9   price                           49010 non-null  int64
#  10  minimum_nights                  49010 non-null  int64
#  11  number_of_reviews               49010 non-null  int64
# ...

# %%
final_df.isnull().any() # Considering the columns with non null values
# Out:
# index                             False
# id                                False
# name                               True
# host_id                           False
# host_name                          True
# neighbourhood_group                True
# neighbourhood                     False
# latitude                          False
# longitude                         False
# room_type                         False
# price                             False
# minimum_nights                    False
# number_of_reviews                 False
# last_review                        True
# reviews_per_month                  True
# calculated_host_listings_count    False
# availability_365                  False
# number_of_reviews_ltm             False
# license                            True
# location                          False
# dtype: bool

# %%
licence_count = final_df.license.isna().sum()
name_count = final_df.name.isna().sum()
reviews_per_month_count = final_df.reviews_per_month.isna().sum()
last_review_count = final_df.last_review.isna().sum()
host_name_count = final_df.host_name.isna().sum()
neighbourhood_group_count = final_df.neighbourhood_group.isna().sum()
print(licence_count)
print(name_count) # 13 houses does not have any name
print(reviews_per_month_count) # there are 10896 houses with no reviews
print(last_review_count)  # there are 10896 houses with no reviews
print(host_name_count) # there are 5 houses whose host information is not available
print(neighbourhood_group_count) # New Jersey and washington DC does not have any neighbourhood groups
# Out:
# 45636
# 13
# 10896
# 10896
# 5
# 7477

# %% [markdown]
# Licence, Reviews per month , last review, neighbourhood_group, host_name and name columns has null values which means that the dataset has no information of these details. So, Dropping Licence column only and keepig other columns as licence column only has highest number of null values and it is not quite useful for analysis

# %%
final_df = final_df.drop(columns='license')

# %% [markdown]
# ### Lets find number of unique rows in each column

# %%
unique_nums = final_df.nunique()
unique_nums
# Out:
# index                             41533
# id                                49010
# name                              47435
# host_id                           30562
# host_name                         10735
# neighbourhood_group                   5
# neighbourhood                       267
# latitude                          24867
# longitude                         23534
# room_type                             4
# price                              1324
# minimum_nights                      129
# number_of_reviews                   522
# last_review                        2780
# reviews_per_month                   978
# calculated_host_listings_count       74
# availability_365                    366
# number_of_reviews_ltm               179
# location                              3
# dtype: int64

# %% [markdown]
# #### As we can see there are 5 unique neighbourhood groups and 4 unique room types. Lets check the unique categories of neighbourhood groups and room types

# %%
final_df.neighbourhood_group.unique() # There are 5 neighbourhood groups in New york but no neighbourhood groups in Washington DC and New Jersey
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Bronx', 'Staten Island', nan],
#       dtype=object)

# %%
final_df.room_type.unique() # There are 4 types of rooms available in Airbnb
# Out:
# array(['Entire home/apt', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %%
final_df.reset_index(inplace = True)

# %%
final_df
# Out:
#        level_0  index        id  \
# 0            0      0      5136
# 1            1      1      5203
# 2            2      2      5121
# 3            3      3      5178
# 4            4      4      2595
# ...        ...    ...       ...
# 49005    49005   6212  13853404
# 49006    49006   6213  13894976
# 49007    49007   6214  13913413
# 49008    49008   6215  13913758
# 49009    49009   6216  13926632
#
#                                                     name   host_id  host_name  \
# 0               Spacious Brooklyn Duplex, Patio + Garden      7378    Rebecca
# 1                     Cozy Clean Guest Room - Family Apt      7490  MaryEllen
# 2                                        BlissArtsSpace!      7356      Garon
# 3                       Large Furnished Room Near B'way　      8967   Shunichi
# 4                                  Skylit Midtown Castle      2845   Jennifer
# ...                                                  ...       ...        ...
# ...

# %%
result = final_df[final_df['last_review'].isnull()]

# %%
result
# Out:
#        level_0  index                  id  \
# 20          20     20               11943
# 35          35     35               63588
# 48          48     48               64015
# 98          98     98               45935
# 102        102    102               68253
# ...        ...    ...                 ...
# 48996    48996   6203  742680913425996077
# 48997    48997   6204  742826875705727714
# 48999    48999   6206  743532059567945583
# 49001    49001   6208  744118763217783794
# 49005    49005   6212            13853404
#
#                                                     name    host_id  \
# 20                             Country space in the city      45445
# 35                                                   LL3     295128
# 48                          Prime East Village 1 Bedroom     146944
# 98                          Room in Beautiful Townhouse.     204586
# 102                         Room in the heart of Astoria      67730
# ...

# %%
resultt = final_df[final_df['number_of_reviews'] == 0 ]

# %%
resultt
# Out:
#        level_0  index                  id  \
# 20          20     20               11943
# 35          35     35               63588
# 48          48     48               64015
# 98          98     98               45935
# 102        102    102               68253
# ...        ...    ...                 ...
# 48996    48996   6203  742680913425996077
# 48997    48997   6204  742826875705727714
# 48999    48999   6206  743532059567945583
# 49001    49001   6208  744118763217783794
# 49005    49005   6212            13853404
#
#                                                     name    host_id  \
# 20                             Country space in the city      45445
# 35                                                   LL3     295128
# 48                          Prime East Village 1 Bedroom     146944
# 98                          Room in Beautiful Townhouse.     204586
# 102                         Room in the heart of Astoria      67730
# ...

# %%
if result.equals(resultt):
  print(True)
# Out:
# True

# %% [markdown]
# ## This shows that therea re 10896 rows in dataset ( housings) which has 0 reviews and thus last_review  and reviews_per_month is NaN. So last_review date cannot be imputed or interpolated because those have 0 reviews. These rows are not getting dropped because they are other columns in this rows which has useful information and 10896 is a huge portion of actual data

# %%
final_df.reviews_per_month.fillna(0, inplace=True)

# %%
final_df.isnull().any()
# Out:
# level_0                           False
# index                             False
# id                                False
# name                               True
# host_id                           False
# host_name                          True
# neighbourhood_group                True
# neighbourhood                     False
# latitude                          False
# longitude                         False
# room_type                         False
# price                             False
# minimum_nights                    False
# number_of_reviews                 False
# last_review                        True
# reviews_per_month                 False
# calculated_host_listings_count    False
# availability_365                  False
# number_of_reviews_ltm             False
# location                          False
# dtype: bool

# %% [markdown]
# ## Name, host_name, last_review and neighbourhood_group are having only considerable Nan values and hence not getting dropped

# %%
final_df['price'].plot()

# %%
fig = plt.figure(dpi= 150)
plt.plot(final_df['price'])
plt.show()

# %%
final_df[final_df['price'] > 10000]
# Out:
#        level_0  index                  id  \
# 9256      9256   9256            15604499
# 9645      9645   9645            16289102
# 31527    31527  31527  563183407738604083
# 32847    32847  32847  603665411466936794
# 34895    34895  34895  658503812592195974
# 37257    37257  37257  706066765395654135
# 43488    43488    695            12202079
#
#                                                     name    host_id  \
# 9256                          The Parachute Loft Bedrm 1   62605071
# 9645     Comfy private room, great location to Manhattan   92493393
# 31527       A cozy one bedroom in ocean hill Brooklyn...  422985413
# 32847                                    New York Estate   34906299
# 34895  Big 2 bedroom two bathroom in a doorman building.  363776653
# 37257                            Zll White Favorite Room  445395972
# 43488   Charming Victorian in the heart of Washington DC   15365907
#
# ...

# %% [markdown]
# ### There are 7 housings in the dataset whose price is above 10000 dollars. These rows are not getting dropped because there might be a chance that hosts may list luxury houses and hence this will be useful for analysis
